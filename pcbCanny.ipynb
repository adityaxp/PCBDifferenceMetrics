# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np


def imshow(title = "", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspectRatio = w / h
    plt.figure(figsize=(size * aspectRatio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
def difference(val1, val2):
    setContours1 = set(map(tuple, [np.ravel(contour).tolist() for contour in val1]))
    setContours2 = set(map(tuple, [np.ravel(contour).tolist() for contour in val2]))

    diffContours = setContours1 - setContours2

    numDiffContours = len(diffContours)
    print(f"Number of different contours: {numDiffContours}")

# %%
image = cv2.imread('./pcb-1-1242164.jpg')

grayScaleImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
edgedImage = cv2.Canny(grayScaleImage, 30, 200)

contours, hierarchy = cv2.findContours(edgedImage, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(grayScaleImage, contours, -1, (0, 255, 0), thickness=4)


cv2.drawContours(image, contours, -1, (0, 255, 0), thickness=4)

imshow('GrayScale', grayScaleImage)
imshow('Contours', image)

# %%
image2 = cv2.imread('./SEG_DVD_430_-_Printed_circuit_board-4276.jpg')

grayScaleImage2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
edgedImage2 = cv2.Canny(grayScaleImage2, 30, 200)

contours2, hierarchy = cv2.findContours(edgedImage2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(grayScaleImage2, contours2, -1, (0, 255, 0), thickness=4)


cv2.drawContours(image2, contours2, -1, (0, 255, 0), thickness=4)

imshow('GrayScale', grayScaleImage2)
imshow('Contours', image2)

# %%
difference(contours, contours2)
# Out:
# Number of different contours: 2746
